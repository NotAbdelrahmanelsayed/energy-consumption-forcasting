# %%
import pandas as pd

# %%
# reading the data
energy_df = pd.read_csv('data/energy.csv')
water = pd.read_csv('data/wc.csv')

# %%
print(len(energy_df))
energy_df.head(
    
)
# Out:
# 366
#                name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  alexandria egypt  2022-01-01     17.0      6.0  11.8          17.0
# 1  alexandria egypt  2022-01-02     19.0      9.0  14.3          19.0
# 2  alexandria egypt  2022-01-03     20.1     13.0  15.8          20.1
# 3  alexandria egypt  2022-01-04     18.1     12.0  15.4          18.1
# 4  alexandria egypt  2022-01-05     19.9      9.0  14.6          19.9
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0           6.0       11.8  10.0      88.1  ...         12.2        6
# 1           7.6       14.2  11.4      83.7  ...          9.6        5
# 2          13.0       15.8  12.0      78.7  ...         11.8        6
# 3          12.0       15.4  11.2      76.4  ...          9.8        5
# 4           7.3       14.6  10.4      75.2  ...         12.9        6
#
#    severerisk              sunrise               sunset  moonphase  \
# ...

# %%
water.head()
# Out:
#   LANDUSE_TYPE                   USER  PIPE DIAM           VENDOR  JAN16  \
# 0           H3        DOMESTICO MEDIO        0.5       MSDELAUNET  197.0
# 1           H3  DOMESTICO RESIDENCIAL        0.5              NaN    NaN
# 2           H3        DOMESTICO MEDIO        0.5              NaN    NaN
# 3           H3  DOMESTICO RESIDENCIAL        0.5              NaN    NaN
# 4           H3  DOMESTICO RESIDENCIAL        0.5  CICASA MMD-15 S  702.0
#
#    2009-01  2009-02  2009-03  2009-04  2009-05  ...  2015-03  2015-04  \
# 0       20       20       20       20       20  ...        2        1
# 1       20       20       20       20       20  ...       27       27
# 2       20       20       20       20       20  ...       19       19
# 3       20       20       20       20       20  ...       17       17
# 4       30       10       30       20       30  ...       14       15
#
#    2015-05  2015-06  2015-07  2015-08  2015-09  2015-10  2015-11  2015-12
# ...

# %%
import tensorflow as tf
# Out:
# C:\Users\bedo7\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import numpy as np
